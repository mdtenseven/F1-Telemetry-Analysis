# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Add any F1 analysis libraries you need

# %%
# Load your F1 telemetry data
# df = pd.read_csv('your_data.csv')

# %%
# Display data info
# df.head()
# df.describe()

# %%
# Create charts/plots
# plt.figure(figsize=(10, 6))
# plt.plot(df['speed'])
# plt.show()

# %%
# Add your findings
