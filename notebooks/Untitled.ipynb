# %%
import fastf1 
import matplotlib.pyplot as plt
import pandas as pd

fastf1.Cache.enable_cache('f1_cache')
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[1], line 5
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
# ----> 5 fastf1.Cache.enable_cache('f1_cache')
#
# File ~/F1 telemetry/F1-Telemetry-Analysis/venv/lib/python3.10/site-packages/fastf1/req.py:242, in Cache.enable_cache(cls, cache_dir, ignore_version, force_renew, use_requests_cache)
#     239 cache_dir = os.path.expanduser(cache_dir)
#     241 if not os.path.exists(cache_dir):
# --> 242     raise NotADirectoryError("Cache directory does not exist! Please "
#     243                              "check for typos or create it first.")
#     244 cls._CACHE_DIR = cache_dir
#     245 cls._IGNORE_VERSION = ignore_version
#
# NotADirectoryError: Cache directory does not exist! Please check for typos or create it first.

# %%
# Load session
session = fastf1.get_session(2024, 'Monaco', 'Q')
session.load()
print(f"Session loaded: {session.event['EventName']} {session.year}")
